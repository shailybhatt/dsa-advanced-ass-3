# %%
#1. Implement Binary tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)

root = BinaryTree(12)
root.insert(9)
root.insert(12)
root.insert(13)

print(root.data, root.left.data, root.right.data, root.left.right.data)
# Out:
# 12 9 13 12

# %%
#2. Find height of a given tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)

    def tree_height(self, root):
        if root is None:
            return -1

        left_height = self.tree_height(root.left)
        right_height = self.tree_height(root.right)

        return max(left_height, right_height) + 1
    
    def inorder(self,root):
        if root is None:
            return -1
        self.inorder(root.left)
        print(root.data,end=' ')
        self.inorder(root.right)
    
    def preorder(self,root):
        if root is None:
            return -1
        print(root.data,end=' ')
        self.preorder(root.left)
        self.preorder(root.right)
    
    def postorder(self,root):
        if root is None:
            return -1
        self.postorder(root.left)
        self.postorder(root.right)
        print(root.data,end=' ')

root = BinaryTree(12)
root.insert(9)
root.insert(12)
root.insert(8)
root.insert(6)
root.insert(4)
root.insert(13)

# root.tree_height(root)
# root.inorder(root)
root.preorder(root)
# root.postorder(root)
# Out:
# 12 9 8 6 4 12 13

# %%
#3. Perform Pre-order, Post-order, In-order traversal

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)
    
    def inorder(self,root):
        if root is None:
            return -1
        self.inorder(root.left)
        print(root.data,end=' ')
        self.inorder(root.right)
    
    def preorder(self,root):
        if root is None:
            return -1
        print(root.data,end=' ')
        self.preorder(root.left)
        self.preorder(root.right)
    
    def postorder(self,root):
        if root is None:
            return -1
        self.postorder(root.left)
        self.postorder(root.right)
        print(root.data,end=' ')

root = BinaryTree(12)
root.insert(9)
root.insert(12)
root.insert(8)
root.insert(6)
root.insert(4)
root.insert(13)

root.inorder(root)
# root.preorder(root)
# root.postorder(root)
# Out:
# 4 6 8 9 12 12 13

# %%
#4. Function to print all the leaves in a given binary tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)
        
    def print_leaves(self, root):
        if root is not None:
            if root.left is None and root.right is None:
                print(root.data)
            else:
                self.print_leaves(root.left)
                self.print_leaves(root.right)



root = BinaryTree(12)
root.insert(9)
root.insert(12)
root.insert(8)
root.insert(6)
root.insert(4)
root.insert(13)

root.print_leaves(root)
# Out:
# 4
# 12
# 13

# %%
#5. Implement BFS (Breath First Search) and DFS (Depth First Search)

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)
    
    def BFS(self):
        if self is None:
            return

        queue = []
        queue.append(self)

        while queue:
            node = queue.pop(0)
            print(node.data, end=" ")

            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)

    def DFS(self):
        if self is None:
            return

        stack = []
        stack.append(self)

        while stack:
            node = stack.pop()
            print(node.data, end=" ")

            if node.right:
                stack.append(node.right)
            if node.left:
                stack.append(node.left)

root = BinaryTree(12)
root.insert(9)
root.insert(12)
root.insert(8)
root.insert(6)
root.insert(4)
root.insert(13)

root.BFS()
root.DFS()
# Out:
# 12 9 13 8 12 6 4 12 9 8 6 4 12 13

# %%
#6. Find sum of all left leaves in a given Binary Tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)
    
    def sum_left_leaves(self):
        if self is None:
            return 0
        
        sum_left = 0
        
        if self.left:
            if self.left.left is None and self.left.right is None:
                sum_left += self.left.data
            else:
                sum_left += self.left.sum_left_leaves()
                
        if self.right:
            sum_left += self.right.sum_left_leaves()
        
        return sum_left

root = BinaryTree(20)
root.insert(9)
root.insert(25)
root.insert(5)
root.insert(12)
root.insert(11)
root.insert(14)
root.insert(27)

print(root.sum_left_leaves())
# Out:
# 16

# %%
#7. Find sum of all nodes of the given perfect binary tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)

    def sum_nodes(self):
        if self is None:
            return 0
        return self.data + self.left.sum_nodes() + self.right.sum_nodes() if self.left and self.right else self.data + (self.left.sum_nodes() if self.left else 0) + (self.right.sum_nodes() if self.right else 0)

root = BinaryTree(20)
root.insert(9)
root.insert(25)
root.insert(5)
root.insert(12)
root.insert(11)
root.insert(14)
root.insert(27)

print(root.sum_nodes())
# Out:
# 123

# %%
#8. Count subtrees that sum up to a given value x in a binary tree

class getNode:
	def __init__(self, data):
		self.data = data
		self.left = self.right = None

def countSubtreesWithSumX(root, count, x):
	if (not root):
		return 0
	ls = countSubtreesWithSumX(root.left,
							count, x)

	rs = countSubtreesWithSumX(root.right,
							count, x)
	Sum = ls + rs + root.data

	if (Sum == x):
		count[0] += 1

	return Sum

def countSubtreesWithSumXUtil(root, x):
	if (not root):
		return 0
	count = [0]
	ls = countSubtreesWithSumX(root.left,count, x)

	rs = countSubtreesWithSumX(root.right,count, x)

	if ((ls + rs + root.data) == x):
		count[0] += 1

	return count[0]


root = getNode(5)
root.left = getNode(-10)
root.right = getNode(3)
root.left.left = getNode(9)
root.left.right = getNode(8)
root.right.left = getNode(-4)
root.right.right = getNode(7)

x = 7

print("Count =",
	countSubtreesWithSumXUtil(root, x))
# Out:
# Count = 2

# %%
#9. Find maximum level sum in Binary Tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)

    def max_level_sum(self):
        if self.data is None:
            return 0

        max_sum = float('-inf')
        queue = [self]

        while queue:
            level_sum = 0
            level_size = len(queue)

            for _ in range(level_size):
                node = queue.pop(0)
                level_sum += node.data

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            max_sum = max(max_sum, level_sum)

        return max_sum

root = BinaryTree(1)
root.left = BinaryTree(2)
root.right = BinaryTree(3)
root.left.left = BinaryTree(4)
root.left.right = BinaryTree(5)
root.right.right = BinaryTree(6)

print(root.max_level_sum())
# Out:
# 15

# %%
#10. Print the nodes at odd levels of a tree

class BinaryTree:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

    def insert(self, data):
        if self.data is None:
            self.data = data
            return

        if data <= self.data:
            if self.left:
                self.left.insert(data)
            else:
                self.left = BinaryTree(data)
        else:
            if self.right:
                self.right.insert(data)
            else:
                self.right = BinaryTree(data)

    def print_odd_level_nodes(self, level=1):
        if self is None:
            return

        if level % 2 != 0:
            print(self.data, end=' ')

        if self.left:
            self.left.print_odd_level_nodes(level + 1)
        if self.right:
            self.right.print_odd_level_nodes(level + 1)

root = BinaryTree(1)
root.left = BinaryTree(2)
root.right = BinaryTree(3)
root.left.left = BinaryTree(4)
root.left.right = BinaryTree(5)
root.right.left = BinaryTree(6)
root.right.right = BinaryTree(7)

root.print_odd_level_nodes()
# Out:
# 1 4 5 6 7
